# %%
# 19CSE305 ML - Pandas Exercise Questions - 30th Sep 2022
### Task 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %%
import pandas as pd
### Task 2. Download the dataset to your computer and unzip it.

# %%
### Task 3. Use the tsv file and assign it to a dataframe called food
food=pd.read_csv("archive (2)\en.openfoodfacts.org.products.tsv",sep='\t',low_memory=False)

# %%
food
# Out:
#                  code                                                url  \
# 0       0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1       0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2       0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3       0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4       0000000016094  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# 356023  9970229501521  http://world-en.openfoodfacts.org/product/9970...
# 356024  9977471758307  http://world-en.openfoodfacts.org/product/9977...
# 356025  9980282863788  http://world-en.openfoodfacts.org/product/9980...
# 356026   999990026839  http://world-en.openfoodfacts.org/product/9999...
#
#                            creator   created_t      created_datetime  \
# 0       openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1                  usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2                  usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3                  usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4                  usda-ndb-import  1489055653  2017-03-09T10:34:13Z
# ...                            ...         ...                   ...
# 356022             usda-ndb-import  1489059076  2017-03-09T11:31:16Z
# 356023                      tomato  1422099377  2015-01-24T11:36:17Z
# 356024  openfoodfacts-contributors  1497018549  2017-06-09T14:29:09Z
# 356025  openfoodfacts-contributors  1492340089  2017-04-16T10:54:49Z
# 356026             usda-ndb-import  1489072709  2017-03-09T15:18:29Z
#
#        last_modified_t last_modified_datetime  \
# 0           1474103893   2016-09-17T09:18:13Z
# 1           1489069957   2017-03-09T14:32:37Z
# 2           1489069957   2017-03-09T14:32:37Z
# 3           1489055731   2017-03-09T10:35:31Z
# 4           1489055653   2017-03-09T10:34:13Z
# ...                ...                    ...
# 356022      1491244499   2017-04-03T18:34:59Z
# 356023      1491244499   2017-04-03T18:34:59Z
# 356024      1500730305   2017-07-22T13:31:45Z
# 356025      1492340089   2017-04-16T10:54:49Z
# 356026      1491244499   2017-04-03T18:34:59Z
#
#                                              product_name  \
# 0                                      Farine de blé noir
# 1                          Banana Chips Sweetened (Whole)
# 2                                                 Peanuts
# 3                                  Organic Salted Nut Mix
# 4                                         Organic Polenta
# ...                                                   ...
# 356022  Mint Melange Tea A Blend Of Peppermint, Lemon ...
# 356023                                            乐吧泡菜味薯片
# 356024                                      Biscottes bio
# 356025                           Tomates aux Vermicelles
# 356026                    Sugar Free Drink Mix, Peach Tea
#
#                            generic_name quantity  ...  \
# 0                                   NaN      1kg  ...
# 1                                   NaN      NaN  ...
# 2                                   NaN      NaN  ...
# 3                                   NaN      NaN  ...
# 4                                   NaN      NaN  ...
# ...                                 ...      ...  ...
# 356022                              NaN      NaN  ...
# 356023  Leba pickle flavor potato chips     50 g  ...
# 356024                              NaN     300g  ...
# 356025                              NaN      67g  ...
# 356026                              NaN      NaN  ...
#
#        fruits-vegetables-nuts_100g fruits-vegetables-nuts-estimate_100g  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# ...                            ...                                  ...
# 356022                         NaN                                  NaN
# 356023                         NaN                                  NaN
# 356024                         NaN                                  NaN
# 356025                         NaN                                  NaN
# 356026                         NaN                                  NaN
#
#        collagen-meat-protein-ratio_100g cocoa_100g chlorophyl_100g  \
# 0                                   NaN        NaN             NaN
# 1                                   NaN        NaN             NaN
# 2                                   NaN        NaN             NaN
# 3                                   NaN        NaN             NaN
# 4                                   NaN        NaN             NaN
# ...                                 ...        ...             ...
# 356022                              NaN        NaN             NaN
# 356023                              NaN        NaN             NaN
# 356024                              NaN        NaN             NaN
# 356025                              NaN        NaN             NaN
# 356026                              NaN        NaN             NaN
#
#        carbon-footprint_100g nutrition-score-fr_100g nutrition-score-uk_100g  \
# 0                        NaN                     NaN                     NaN
# 1                        NaN                    14.0                    14.0
# 2                        NaN                     0.0                     0.0
# 3                        NaN                    12.0                    12.0
# 4                        NaN                     NaN                     NaN
# ...                      ...                     ...                     ...
# 356022                   NaN                     0.0                     0.0
# 356023                   NaN                     NaN                     NaN
# 356024                   NaN                     NaN                     NaN
# 356025                   NaN                     NaN                     NaN
# 356026                   NaN                     NaN                     NaN
#
#        glycemic-index_100g water-hardness_100g
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ...                    ...                 ...
# 356022                 NaN                 NaN
# 356023                 NaN                 NaN
# 356024                 NaN                 NaN
# 356025                 NaN                 NaN
# 356026                 NaN                 NaN
#
# [356027 rows x 163 columns]

# %%
### Task 4. See the first 5 entries

food.head()
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1  0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2  0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3  0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4  0000000016094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
# [5 rows x 163 columns]

# %%
### Task 5. What is the number of observations in the dataset?

len(food)
# Out:
# 356027

# %%
### Task 6. What is the number of columns in the dataset?
len(food.columns)
# Out:
# 163

# %%
### Task 7. Print the name of all the columns.
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
### Task 8. What is the name of 105th column?

food.columns[104]
# Out:
# '-glucose_100g'

# %%
### Task 9. What is the type of the observations of the 105th column?
type(food.columns[104])
# Out:
# str

# %%
### Task 10. How is the dataset indexed?
food.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %%
### Task 11. What is the product name of the 19th observation?

food['product_name'][18]
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %%
### Task 12. How many columns in the dataset tend have null values?
sum=0
for i in food.isnull().sum():
    if i>0:
        sum+=1
print(sum)
# Out:
# 161

# %%
### Task 13. Find the number of null values present under each column?
food.isnull().sum()
# Out:
# code                           26
# url                            26
# creator                         3
# created_t                       3
# created_datetime               10
#                             ...
# carbon-footprint_100g      355749
# nutrition-score-fr_100g    101171
# nutrition-score-uk_100g    101171
# glycemic-index_100g        356027
# water-hardness_100g        356027
# Length: 163, dtype: int64

# %%
### Task 14. Create a dictionary with keys to be column names in the dataset and values to number of values under each column. Print the dictionary by iterating through its elements using a for loop.  

dict={}
for i in food.columns:
    dict[i]=len(food)-food.isnull().sum()[i]

for i in dict.items():
    print(i)
# Out:
# ('code', 356001)
# ('url', 356001)
# ('creator', 356024)
# ('created_t', 356024)
# ('created_datetime', 356017)
# ('last_modified_t', 356027)
# ('last_modified_datetime', 356027)
# ('product_name', 338515)
# ('generic_name', 57714)
# ('quantity', 119285)
# ('packaging', 89959)
# ('packaging_tags', 89959)
# ('brands', 326977)
# ('brands_tags', 326957)
# ('categories', 103299)
# ('categories_tags', 103275)
# ('categories_en', 103301)
# ('origins', 25050)
# ('origins_tags', 25012)
# ('manufacturing_places', 42008)
# ('manufacturing_places_tags', 42001)
# ('labels', 59098)
# ('labels_tags', 59178)
# ('labels_en', 59204)
# ('emb_codes', 32490)
# ('emb_codes_tags', 32486)
# ('first_packaging_code_geo', 20872)
# ('cities', 26)
# ('cities_tags', 22502)
# ('purchase_places', 66565)
# ('stores', 57701)
# ('countries', 355752)
# ('countries_tags', 355752)
# ('countries_en', 355752)
# ('ingredients_text', 283893)
# ('allergens', 37176)
# ('allergens_en', 20)
# ('traces', 28421)
# ('traces_tags', 28394)
# ('traces_en', 28420)
# ('serving_size', 216621)
# ('no_nutriments', 0)
# ('additives_n', 283867)
# ('additives', 283825)
# ('additives_tags', 170189)
# ('additives_en', 170189)
# ('ingredients_from_palm_oil_n', 283867)
# ('ingredients_from_palm_oil', 0)
# ('ingredients_from_palm_oil_tags', 6572)
# ('ingredients_that_may_be_from_palm_oil_n', 283867)
# ('ingredients_that_may_be_from_palm_oil', 0)
# ('ingredients_that_may_be_from_palm_oil_tags', 14328)
# ('nutrition_grade_uk', 0)
# ('nutrition_grade_fr', 254856)
# ('pnns_groups_1', 129006)
# ('pnns_groups_2', 132689)
# ('states', 355975)
# ('states_tags', 355975)
# ('states_en', 355975)
# ('main_category', 103249)
# ('main_category_en', 103249)
# ('image_url', 75725)
# ('image_small_url', 75725)
# ('energy_100g', 295367)
# ('energy-from-fat_100g', 869)
# ('fat_100g', 279497)
# ('saturated-fat_100g', 263823)
# ('-butyric-acid_100g', 0)
# ('-caproic-acid_100g', 0)
# ('-caprylic-acid_100g', 1)
# ('-capric-acid_100g', 2)
# ('-lauric-acid_100g', 4)
# ('-myristic-acid_100g', 1)
# ('-palmitic-acid_100g', 1)
# ('-stearic-acid_100g', 1)
# ('-arachidic-acid_100g', 27)
# ('-behenic-acid_100g', 26)
# ('-lignoceric-acid_100g', 0)
# ('-cerotic-acid_100g', 0)
# ('-montanic-acid_100g', 1)
# ('-melissic-acid_100g', 0)
# ('monounsaturated-fat_100g', 23040)
# ('polyunsaturated-fat_100g', 23075)
# ('omega-3-fat_100g', 938)
# ('-alpha-linolenic-acid_100g', 201)
# ('-eicosapentaenoic-acid_100g', 43)
# ('-docosahexaenoic-acid_100g', 89)
# ('omega-6-fat_100g', 207)
# ('-linoleic-acid_100g', 159)
# ('-arachidonic-acid_100g', 9)
# ('-gamma-linolenic-acid_100g', 27)
# ('-dihomo-gamma-linolenic-acid_100g', 26)
# ('omega-9-fat_100g', 25)
# ('-oleic-acid_100g', 15)
# ('-elaidic-acid_100g', 0)
# ('-gondoic-acid_100g', 16)
# ('-mead-acid_100g', 0)
# ('-erucic-acid_100g', 0)
# ('-nervonic-acid_100g', 0)
# ('trans-fat_100g', 143443)
# ('cholesterol_100g', 144170)
# ('carbohydrates_100g', 279220)
# ('sugars_100g', 279186)
# ('-sucrose_100g', 85)
# ('-glucose_100g', 32)
# ('-fructose_100g', 44)
# ('-lactose_100g', 278)
# ('-maltose_100g', 6)
# ('-maltodextrins_100g', 11)
# ('starch_100g', 291)
# ('polyols_100g', 451)
# ('fiber_100g', 220683)
# ('proteins_100g', 294161)
# ('casein_100g', 29)
# ('serum-proteins_100g', 17)
# ('nucleotides_100g', 9)
# ('salt_100g', 289739)
# ('sodium_100g', 289694)
# ('alcohol_100g', 4577)
# ('vitamin-a_100g', 137706)
# ('beta-carotene_100g', 35)
# ('vitamin-d_100g', 7207)
# ('vitamin-e_100g', 1472)
# ('vitamin-k_100g', 930)
# ('vitamin-c_100g', 141060)
# ('vitamin-b1_100g', 11277)
# ('vitamin-b2_100g', 10925)
# ('vitamin-pp_100g', 11831)
# ('vitamin-b6_100g', 6897)
# ('vitamin-b9_100g', 5330)
# ('folates_100g', 3046)
# ('vitamin-b12_100g', 5390)
# ('biotin_100g', 331)
# ('pantothenic-acid_100g', 2551)
# ('silica_100g', 73)
# ('bicarbonate_100g', 99)
# ('potassium_100g', 24848)
# ('chloride_100g', 198)
# ('calcium_100g', 141517)
# ('phosphorus_100g', 5938)
# ('iron_100g', 140660)
# ('magnesium_100g', 6392)
# ('zinc_100g', 3964)
# ('copper_100g', 2122)
# ('manganese_100g', 1639)
# ('fluoride_100g', 99)
# ('selenium_100g', 1181)
# ('chromium_100g', 23)
# ('molybdenum_100g', 20)
# ('iodine_100g', 288)
# ('caffeine_100g', 91)
# ('taurine_100g', 33)
# ('ph_100g', 52)
# ('fruits-vegetables-nuts_100g', 3228)
# ('fruits-vegetables-nuts-estimate_100g', 404)
# ('collagen-meat-protein-ratio_100g', 182)
# ('cocoa_100g', 1383)
# ('chlorophyl_100g', 0)
# ('carbon-footprint_100g', 278)
# ('nutrition-score-fr_100g', 254856)
# ('nutrition-score-uk_100g', 254856)
# ('glycemic-index_100g', 0)
# ('water-hardness_100g', 0)

# %%
### Task 15. Display the values associated with all columns from row 108 to 208?
food.loc[108:208]
# Out:
#               code                                                url  \
# 108  0000000036252  http://world-en.openfoodfacts.org/product/0000...
# 109  0000000036269  http://world-en.openfoodfacts.org/product/0000...
# 110  0000000036276  http://world-en.openfoodfacts.org/product/0000...
# 111  0000000036986  http://world-en.openfoodfacts.org/product/0000...
# 112  0000000038058  http://world-en.openfoodfacts.org/product/0000...
# ..             ...                                                ...
# 204  0000020043087  http://world-en.openfoodfacts.org/product/0000...
# 205  0000020043124  http://world-en.openfoodfacts.org/product/0000...
# 206  0000020043131  http://world-en.openfoodfacts.org/product/0000...
# 207  0000020044015  http://world-en.openfoodfacts.org/product/0000...
# 208  0000020044480  http://world-en.openfoodfacts.org/product/0000...
#
#              creator   created_t      created_datetime last_modified_t  \
# 108          tacinte  1422221701  2015-01-25T21:35:01Z      1494824741
# 109  usda-ndb-import  1489055651  2017-03-09T10:34:11Z      1489055651
# 110  usda-ndb-import  1489055678  2017-03-09T10:34:38Z      1489055678
# 111  usda-ndb-import  1489055649  2017-03-09T10:34:09Z      1489055649
# 112  usda-ndb-import  1489055651  2017-03-09T10:34:11Z      1489055651
# ..               ...         ...                   ...             ...
# 204  usda-ndb-import  1489135780  2017-03-10T08:49:40Z      1489135780
# 205  usda-ndb-import  1489133902  2017-03-10T08:18:22Z      1489133902
# 206  usda-ndb-import  1489133434  2017-03-10T08:10:34Z      1489133434
# 207  usda-ndb-import  1489133902  2017-03-10T08:18:22Z      1489133902
# 208  usda-ndb-import  1489133434  2017-03-10T08:10:34Z      1489133434
#
#     last_modified_datetime                             product_name  \
# 108   2017-05-15T05:05:41Z                           Lion Peanut x2
# 109   2017-03-09T10:34:11Z  Milk Chocolate Peanut Butter Malt Balls
# 110   2017-03-09T10:34:38Z              Organic Tamari Pumpkin Seed
# 111   2017-03-09T10:34:09Z                          Yogurt Pretzels
# 112   2017-03-09T10:34:11Z                     Organic Kamut Flakes
# ..                     ...                                      ...
# 204   2017-03-10T08:49:40Z                                  Biscuit
# 205   2017-03-10T08:18:22Z                    Oatmeal Raisin Cookie
# 206   2017-03-10T08:10:34Z                       Sliced Plain Bagel
# 207   2017-03-10T08:18:22Z                                    Scone
# 208   2017-03-10T08:10:34Z                   Belgian Vanilla Waffle
#
#     generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 108          NaN      NaN  ...                         NaN
# 109          NaN      NaN  ...                         NaN
# 110          NaN      NaN  ...                         NaN
# 111          NaN      NaN  ...                         NaN
# 112          NaN      NaN  ...                         NaN
# ..           ...      ...  ...                         ...
# 204          NaN      NaN  ...                         NaN
# 205          NaN      NaN  ...                         NaN
# 206          NaN      NaN  ...                         NaN
# 207          NaN      NaN  ...                         NaN
# 208          NaN      NaN  ...                         NaN
#
#     fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 108                                  NaN                              NaN
# 109                                  NaN                              NaN
# 110                                  NaN                              NaN
# 111                                  NaN                              NaN
# 112                                  NaN                              NaN
# ..                                   ...                              ...
# 204                                  NaN                              NaN
# 205                                  NaN                              NaN
# 206                                  NaN                              NaN
# 207                                  NaN                              NaN
# 208                                  NaN                              NaN
#
#     cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 108        NaN             NaN                   NaN                     NaN
# 109        NaN             NaN                   NaN                    23.0
# 110        NaN             NaN                   NaN                    15.0
# 111        NaN             NaN                   NaN                    30.0
# 112        NaN             NaN                   NaN                     NaN
# ..         ...             ...                   ...                     ...
# 204        NaN             NaN                   NaN                    18.0
# 205        NaN             NaN                   NaN                    21.0
# 206        NaN             NaN                   NaN                     2.0
# 207        NaN             NaN                   NaN                    19.0
# 208        NaN             NaN                   NaN                    25.0
#
#     nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 108                     NaN                 NaN                 NaN
# 109                    23.0                 NaN                 NaN
# 110                    15.0                 NaN                 NaN
# 111                    30.0                 NaN                 NaN
# 112                     NaN                 NaN                 NaN
# ..                      ...                 ...                 ...
# 204                    18.0                 NaN                 NaN
# 205                    21.0                 NaN                 NaN
# 206                     2.0                 NaN                 NaN
# 207                    19.0                 NaN                 NaN
# 208                    25.0                 NaN                 NaN
#
# [101 rows x 163 columns]
